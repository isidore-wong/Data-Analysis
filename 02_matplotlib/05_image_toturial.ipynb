# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
img = Image.open('./datas/001.jpg')
imgplot = plt.imshow(img)

# %%
from PIL import Image
import numpy as np
img = Image.open('./datas/001.jpg')
rsize = img.resize((img.size[0],img.size[1]))
rsizeArr = np.asarray(rsize) 
imgplot = plt.imshow(rsizeArr)
